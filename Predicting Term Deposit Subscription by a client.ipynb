# %% [markdown]
# # Predicting Term Deposit Subscription by a client

# %% [markdown]
# ### Import Packages

# %%
# Import basic packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
     
# Import label encoder, chi2, model selection
from scipy.stats import chi2_contingency
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
     
# Import Model and scores
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.svm import SVC

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv(r"C:\Users\palla\Downloads\Datasets\bank-additional-full.csv", header=None)

# %%
df
# Out:
#                                                        0
# 0      age;job;marital;education;default;housing;loan...
# 1      56;"housemaid";"married";"basic.4y";"no";"no";...
# 2      57;"services";"married";"high.school";"unknown...
# 3      37;"services";"married";"high.school";"no";"ye...
# 4      40;"admin.";"married";"basic.6y";"no";"no";"no...
# ...                                                  ...
# 41184  73;"retired";"married";"professional.course";"...
# 41185  46;"blue-collar";"married";"professional.cours...
# 41186  56;"retired";"married";"university.degree";"no...
# 41187  44;"technician";"married";"professional.course...
# 41188  74;"retired";"married";"professional.course";"...
#
# [41189 rows x 1 columns]

# %% [markdown]
# ## Exploratory Data Analysis & Feature Engineering (EDA & FE)
# ### Treating Features Data

# %%
# split column into multiple columns by delimiter
df = df[0].str.split(';', expand=True)

# %%
df
# Out:
#         0              1          2                      3          4
# 0      age            job    marital              education    default  \
# 1       56    "housemaid"  "married"             "basic.4y"       "no"
# 2       57     "services"  "married"          "high.school"  "unknown"
# 3       37     "services"  "married"          "high.school"       "no"
# 4       40       "admin."  "married"             "basic.6y"       "no"
# ...    ...            ...        ...                    ...        ...
# 41184   73      "retired"  "married"  "professional.course"       "no"
# 41185   46  "blue-collar"  "married"  "professional.course"       "no"
# 41186   56      "retired"  "married"    "university.degree"       "no"
# 41187   44   "technician"  "married"  "professional.course"       "no"
# 41188   74      "retired"  "married"  "professional.course"       "no"
#
#             5     6            7      8            9   ...        11     12
# 0      housing  loan      contact  month  day_of_week  ...  campaign  pdays  \
# 1         "no"  "no"  "telephone"  "may"        "mon"  ...         1    999
# 2         "no"  "no"  "telephone"  "may"        "mon"  ...         1    999
# 3        "yes"  "no"  "telephone"  "may"        "mon"  ...         1    999
# 4         "no"  "no"  "telephone"  "may"        "mon"  ...         1    999
# ...        ...   ...          ...    ...          ...  ...       ...    ...
# 41184    "yes"  "no"   "cellular"  "nov"        "fri"  ...         1    999
# 41185     "no"  "no"   "cellular"  "nov"        "fri"  ...         1    999
# 41186    "yes"  "no"   "cellular"  "nov"        "fri"  ...         2    999
# 41187     "no"  "no"   "cellular"  "nov"        "fri"  ...         1    999
# 41188    "yes"  "no"   "cellular"  "nov"        "fri"  ...         3    999
#
#              13             14            15              16             17
# 0      previous       poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 1             0  "nonexistent"           1.1          93.994          -36.4
# 2             0  "nonexistent"           1.1          93.994          -36.4
# 3             0  "nonexistent"           1.1          93.994          -36.4
# 4             0  "nonexistent"           1.1          93.994          -36.4
# ...         ...            ...           ...             ...            ...
# 41184         0  "nonexistent"          -1.1          94.767          -50.8
# 41185         0  "nonexistent"          -1.1          94.767          -50.8
# 41186         0  "nonexistent"          -1.1          94.767          -50.8
# 41187         0  "nonexistent"          -1.1          94.767          -50.8
# 41188         1      "failure"          -1.1          94.767          -50.8
#
#               18           19     20
# 0      euribor3m  nr.employed      y
# 1          4.857         5191   "no"
# 2          4.857         5191   "no"
# 3          4.857         5191   "no"
# 4          4.857         5191   "no"
# ...          ...          ...    ...
# 41184      1.028       4963.6  "yes"
# 41185      1.028       4963.6   "no"
# 41186      1.028       4963.6   "no"
# 41187      1.028       4963.6  "yes"
# 41188      1.028       4963.6   "no"
#
# [41189 rows x 21 columns]

# %%
# Making the 1st row as Column or features
df.columns=df.iloc[0]
df
# Out:
# 0      age            job    marital              education    default
# 0      age            job    marital              education    default  \
# 1       56    "housemaid"  "married"             "basic.4y"       "no"
# 2       57     "services"  "married"          "high.school"  "unknown"
# 3       37     "services"  "married"          "high.school"       "no"
# 4       40       "admin."  "married"             "basic.6y"       "no"
# ...    ...            ...        ...                    ...        ...
# 41184   73      "retired"  "married"  "professional.course"       "no"
# 41185   46  "blue-collar"  "married"  "professional.course"       "no"
# 41186   56      "retired"  "married"    "university.degree"       "no"
# 41187   44   "technician"  "married"  "professional.course"       "no"
# 41188   74      "retired"  "married"  "professional.course"       "no"
#
# 0      housing  loan      contact  month  day_of_week  ...  campaign  pdays
# 0      housing  loan      contact  month  day_of_week  ...  campaign  pdays  \
# 1         "no"  "no"  "telephone"  "may"        "mon"  ...         1    999
# 2         "no"  "no"  "telephone"  "may"        "mon"  ...         1    999
# 3        "yes"  "no"  "telephone"  "may"        "mon"  ...         1    999
# 4         "no"  "no"  "telephone"  "may"        "mon"  ...         1    999
# ...        ...   ...          ...    ...          ...  ...       ...    ...
# 41184    "yes"  "no"   "cellular"  "nov"        "fri"  ...         1    999
# 41185     "no"  "no"   "cellular"  "nov"        "fri"  ...         1    999
# 41186    "yes"  "no"   "cellular"  "nov"        "fri"  ...         2    999
# 41187     "no"  "no"   "cellular"  "nov"        "fri"  ...         1    999
# 41188    "yes"  "no"   "cellular"  "nov"        "fri"  ...         3    999
#
# 0      previous       poutcome  emp.var.rate  cons.price.idx  cons.conf.idx
# 0      previous       poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 1             0  "nonexistent"           1.1          93.994          -36.4
# 2             0  "nonexistent"           1.1          93.994          -36.4
# 3             0  "nonexistent"           1.1          93.994          -36.4
# 4             0  "nonexistent"           1.1          93.994          -36.4
# ...         ...            ...           ...             ...            ...
# 41184         0  "nonexistent"          -1.1          94.767          -50.8
# 41185         0  "nonexistent"          -1.1          94.767          -50.8
# 41186         0  "nonexistent"          -1.1          94.767          -50.8
# 41187         0  "nonexistent"          -1.1          94.767          -50.8
# 41188         1      "failure"          -1.1          94.767          -50.8
#
# 0      euribor3m  nr.employed      y
# 0      euribor3m  nr.employed      y
# 1          4.857         5191   "no"
# 2          4.857         5191   "no"
# 3          4.857         5191   "no"
# 4          4.857         5191   "no"
# ...          ...          ...    ...
# 41184      1.028       4963.6  "yes"
# 41185      1.028       4963.6   "no"
# 41186      1.028       4963.6   "no"
# 41187      1.028       4963.6  "yes"
# 41188      1.028       4963.6   "no"
#
# [41189 rows x 21 columns]

# %%
# Keeping One duplicate Variable for handling changes in later stages
df1 = df

# %%
# Row 0 is dropped
df1 = df1.drop([0])
df1
# Out:
# 0     age            job    marital              education    default housing
# 1      56    "housemaid"  "married"             "basic.4y"       "no"    "no"  \
# 2      57     "services"  "married"          "high.school"  "unknown"    "no"
# 3      37     "services"  "married"          "high.school"       "no"   "yes"
# 4      40       "admin."  "married"             "basic.6y"       "no"    "no"
# 5      56     "services"  "married"          "high.school"       "no"    "no"
# ...    ..            ...        ...                    ...        ...     ...
# 41184  73      "retired"  "married"  "professional.course"       "no"   "yes"
# 41185  46  "blue-collar"  "married"  "professional.course"       "no"    "no"
# 41186  56      "retired"  "married"    "university.degree"       "no"   "yes"
# 41187  44   "technician"  "married"  "professional.course"       "no"    "no"
# 41188  74      "retired"  "married"  "professional.course"       "no"   "yes"
#
# 0       loan      contact  month day_of_week  ... campaign pdays previous
# 1       "no"  "telephone"  "may"       "mon"  ...        1   999        0  \
# 2       "no"  "telephone"  "may"       "mon"  ...        1   999        0
# 3       "no"  "telephone"  "may"       "mon"  ...        1   999        0
# 4       "no"  "telephone"  "may"       "mon"  ...        1   999        0
# 5      "yes"  "telephone"  "may"       "mon"  ...        1   999        0
# ...      ...          ...    ...         ...  ...      ...   ...      ...
# 41184   "no"   "cellular"  "nov"       "fri"  ...        1   999        0
# 41185   "no"   "cellular"  "nov"       "fri"  ...        1   999        0
# 41186   "no"   "cellular"  "nov"       "fri"  ...        2   999        0
# 41187   "no"   "cellular"  "nov"       "fri"  ...        1   999        0
# 41188   "no"   "cellular"  "nov"       "fri"  ...        3   999        1
#
# 0           poutcome emp.var.rate cons.price.idx cons.conf.idx euribor3m
# 1      "nonexistent"          1.1         93.994         -36.4     4.857  \
# 2      "nonexistent"          1.1         93.994         -36.4     4.857
# 3      "nonexistent"          1.1         93.994         -36.4     4.857
# 4      "nonexistent"          1.1         93.994         -36.4     4.857
# 5      "nonexistent"          1.1         93.994         -36.4     4.857
# ...              ...          ...            ...           ...       ...
# 41184  "nonexistent"         -1.1         94.767         -50.8     1.028
# 41185  "nonexistent"         -1.1         94.767         -50.8     1.028
# 41186  "nonexistent"         -1.1         94.767         -50.8     1.028
# 41187  "nonexistent"         -1.1         94.767         -50.8     1.028
# 41188      "failure"         -1.1         94.767         -50.8     1.028
#
# 0     nr.employed      y
# 1            5191   "no"
# 2            5191   "no"
# 3            5191   "no"
# 4            5191   "no"
# 5            5191   "no"
# ...           ...    ...
# 41184      4963.6  "yes"
# 41185      4963.6   "no"
# 41186      4963.6   "no"
# 41187      4963.6  "yes"
# 41188      4963.6   "no"
#
# [41188 rows x 21 columns]

# %% [markdown]
# ### Data types

# %%
df.isnull().sum()
# Out:
# 0
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
# Finding the Null values in the dataset
df.isna().sum()
# Out:
# 0
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df1.dtypes
# Out:
# 0
# age               object
# job               object
# marital           object
# education         object
# default           object
# housing           object
# loan              object
# contact           object
# month             object
# day_of_week       object
# duration          object
# campaign          object
# pdays             object
# previous          object
# poutcome          object
# emp.var.rate      object
# cons.price.idx    object
# cons.conf.idx     object
# euribor3m         object
# nr.employed       object
# y                 object
# dtype: object

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 1 to 41188
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  object
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  object
#  11  campaign        41188 non-null  object
#  12  pdays           41188 non-null  object
#  13  previous        41188 non-null  object
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  object
#  16  cons.price.idx  41188 non-null  object
#  17  cons.conf.idx   41188 non-null  object
#  18  euribor3m       41188 non-null  object
#  19  nr.employed     41188 non-null  object
#  20  y               41188 non-null  object
# dtypes: object(21)
# memory usage: 6.6+ MB

# %% [markdown]
# ## Features Analysis
#
# ### Treating features data

# %%
# Target variable unique values
df1['y'].unique()
# Out:
# array(['"no"', '"yes"'], dtype=object)

# %%
df1['job'].unique()
# Out:
# array(['"housemaid"', '"services"', '"admin."', '"blue-collar"',
#        '"technician"', '"retired"', '"management"', '"unemployed"',
#        '"self-employed"', '"unknown"', '"entrepreneur"', '"student"'],
#       dtype=object)

# %%
df1['y'].replace(['"no"', '"yes"'],["no", "yes"], inplace=True)

# %%
df1['job'].replace(['"housemaid"', '"services"', '"admin."', '"blue-collar"',
       '"technician"', '"retired"', '"management"', '"unemployed"',
       '"self-employed"', '"unknown"', '"entrepreneur"', '"student"'],['housemaid', 'services', 'admin', 'blue-collar',
       'technician', 'retired', 'management', 'unemployed',
       'self-employed', 'unknown', 'entrepreneur', 'student'], inplace=True)

df1['marital'].replace(['"married"', '"single"', '"divorced"', '"unknown"'],['married', 'single', 'divorced', 'unknown'], inplace=True)

df1['education'].replace(['"basic.4y"', '"high.school"', '"basic.6y"', '"basic.9y"',
       '"professional.course"', '"unknown"', '"university.degree"',
       '"illiterate"'],['basic.4y', 'high.school', 'basic.6y', 'basic.9y',
       'professional.course', 'unknown', 'university.degree',
       'illiterate'], inplace=True)

# %%
df1['default'].replace(['"no"', '"unknown"', '"yes"'],['no', 'unknown', 'yes'], inplace=True)

df1['housing'].replace(['"no"', '"yes"', '"unknown"'],['no', 'yes', 'unknown'], inplace=True)

df1['loan'].replace(['"no"', '"yes"', '"unknown"'],['no', 'yes', 'unknown'], inplace=True)

df1['contact'].replace(['"telephone"', '"cellular"'],['telephone', 'cellular'], inplace=True)

df1['month'].replace(['"may"', '"jun"', '"jul"', '"aug"', '"oct"', '"nov"', '"dec"',
       '"mar"', '"apr"', '"sep"'],['may', 'jun', 'jul', 'aug', 'oct', 'nov', 'dec',
       'mar', 'apr', 'sep'], inplace=True)


df1['day_of_week'].replace(['"mon"', '"tue"', '"wed"', '"thu"', '"fri"'],['mon', 'tue', 'wed', 'thu', 'fri'], inplace=True)


df1['poutcome'].replace(['"nonexistent"', '"failure"', '"success"'],['nonexistent', 'failure', 'success'], inplace=True)

# %%
df1['marital'].unique()
# Out:
# array(['married', 'single', 'divorced', 'unknown'], dtype=object)

# %%
df1['default'].unique()
# Out:
# array(['no', 'unknown', 'yes'], dtype=object)

# %%
df1['housing'].unique()
# Out:
# array(['no', 'yes', 'unknown'], dtype=object)

# %%
df1['loan'].unique()
# Out:
# array(['no', 'yes', 'unknown'], dtype=object)

# %%
df1['contact'].unique()
# Out:
# array(['telephone', 'cellular'], dtype=object)

# %%
df1['month'].unique()
# Out:
# array(['may', 'jun', 'jul', 'aug', 'oct', 'nov', 'dec', 'mar', 'apr',
#        'sep'], dtype=object)

# %%
df1['day_of_week'].unique()
# Out:
# array(['mon', 'tue', 'wed', 'thu', 'fri'], dtype=object)

# %%
df1['poutcome'].unique()
# Out:
# array(['nonexistent', 'failure', 'success'], dtype=object)

# %% [markdown]
# ### Variable Type conversion

# %%
df1.dtypes
# Out:
# 0
# age               object
# job               object
# marital           object
# education         object
# default           object
# housing           object
# loan              object
# contact           object
# month             object
# day_of_week       object
# duration          object
# campaign          object
# pdays             object
# previous          object
# poutcome          object
# emp.var.rate      object
# cons.price.idx    object
# cons.conf.idx     object
# euribor3m         object
# nr.employed       object
# y                 object
# dtype: object

# %%
df1["age"] = pd.to_numeric(df1.age)
df1["campaign"] = pd.to_numeric(df1["campaign"])
df1["pdays"] = pd.to_numeric(df1.pdays)
df1["previous"] = pd.to_numeric(df1.previous)
df1["emp.var.rate"] = pd.to_numeric(df1["emp.var.rate"])
df1["cons.price.idx"] = pd.to_numeric(df1["cons.price.idx"])
df1["cons.conf.idx"] = pd.to_numeric(df1["cons.conf.idx"])
df1["euribor3m"] = pd.to_numeric(df1["euribor3m"])
df1["nr.employed"] = pd.to_numeric(df1["nr.employed"])

# %% [markdown]
# #### Unrecognized dtypes by pandas are treated in this step, object data types converted into numeric data types

# %%
df1.dtypes
# Out:
# 0
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration           object
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %% [markdown]
# ### Statistical summary

# %%
df1.describe()
# Out:
# 0              age      campaign         pdays      previous  emp.var.rate
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000  \
# mean      40.02406      2.567593    962.475454      0.172963      0.081886
# std       10.42125      2.770014    186.910907      0.494901      1.570960
# min       17.00000      1.000000      0.000000      0.000000     -3.400000
# 25%       32.00000      1.000000    999.000000      0.000000     -1.800000
# 50%       38.00000      2.000000    999.000000      0.000000      1.100000
# 75%       47.00000      3.000000    999.000000      0.000000      1.400000
# max       98.00000     56.000000    999.000000      7.000000      1.400000
#
# 0      cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count    41188.000000   41188.000000  41188.000000  41188.000000
# mean        93.575664     -40.502600      3.621291   5167.035911
# std          0.578840       4.628198      1.734447     72.251528
# min         92.201000     -50.800000      0.634000   4963.600000
# 25%         93.075000     -42.700000      1.344000   5099.100000
# 50%         93.749000     -41.800000      4.857000   5191.000000
# 75%         93.994000     -36.400000      4.961000   5228.100000
# max         94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Visualize features & Findings

# %%
df1
# Out:
# 0      age          job  marital            education  default housing loan
# 1       56    housemaid  married             basic.4y       no      no   no  \
# 2       57     services  married          high.school  unknown      no   no
# 3       37     services  married          high.school       no     yes   no
# 4       40        admin  married             basic.6y       no      no   no
# 5       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41184   73      retired  married  professional.course       no     yes   no
# 41185   46  blue-collar  married  professional.course       no      no   no
# 41186   56      retired  married    university.degree       no     yes   no
# 41187   44   technician  married  professional.course       no      no   no
# 41188   74      retired  married  professional.course       no     yes   no
#
# 0        contact month day_of_week  ... campaign  pdays  previous
# 1      telephone   may         mon  ...        1    999         0  \
# 2      telephone   may         mon  ...        1    999         0
# 3      telephone   may         mon  ...        1    999         0
# 4      telephone   may         mon  ...        1    999         0
# 5      telephone   may         mon  ...        1    999         0
# ...          ...   ...         ...  ...      ...    ...       ...
# 41184   cellular   nov         fri  ...        1    999         0
# 41185   cellular   nov         fri  ...        1    999         0
# 41186   cellular   nov         fri  ...        2    999         0
# 41187   cellular   nov         fri  ...        1    999         0
# 41188   cellular   nov         fri  ...        3    999         1
#
# 0         poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m
# 1      nonexistent          1.1          93.994          -36.4      4.857  \
# 2      nonexistent          1.1          93.994          -36.4      4.857
# 3      nonexistent          1.1          93.994          -36.4      4.857
# 4      nonexistent          1.1          93.994          -36.4      4.857
# 5      nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41184  nonexistent         -1.1          94.767          -50.8      1.028
# 41185  nonexistent         -1.1          94.767          -50.8      1.028
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187  nonexistent         -1.1          94.767          -50.8      1.028
# 41188      failure         -1.1          94.767          -50.8      1.028
#
# 0      nr.employed    y
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# 5           5191.0   no
# ...            ...  ...
# 41184       4963.6  yes
# 41185       4963.6   no
# 41186       4963.6   no
# 41187       4963.6  yes
# 41188       4963.6   no
#
# [41188 rows x 21 columns]

# %%
df1["age"].describe()
# Out:
# count    41188.00000
# mean        40.02406
# std         10.42125
# min         17.00000
# 25%         32.00000
# 50%         38.00000
# 75%         47.00000
# max         98.00000
# Name: age, dtype: float64

# %%
#In this box plot we can observe that most of the dataset values age lies in the range of early 20's to 70 and 25th percentile around 32 and 75th percentile around 48. Median lies at 38 aproximately. above age 70, we observe some outliers, so we need to visualize further more to come to some conclusion on the same.
sns.boxplot(data=df1, x="age", hue="y");

# %%
df1[df1['age']>70].count()
# Out:
# 0
# age               422
# job               422
# marital           422
# education         422
# default           422
# housing           422
# loan              422
# contact           422
# month             422
# day_of_week       422
# duration          422
# campaign          422
# pdays             422
# previous          422
# poutcome          422
# emp.var.rate      422
# cons.price.idx    422
# cons.conf.idx     422
# euribor3m         422
# nr.employed       422
# y                 422
# dtype: int64

# %%
df1_ = df1['age'].value_counts()
df1_.tail(20)
# Out:
# age
# 78    27
# 67    26
# 75    24
# 88    22
# 77    20
# 81    20
# 83    17
# 82    17
# 85    15
# 79    14
# 86     8
# 84     7
# 17     5
# 92     4
# 98     2
# 89     2
# 91     2
# 94     1
# 87     1
# 95     1
# Name: count, dtype: int64

# %%
df1_ = df1.groupby('age')['y'].count()
df1_
# Out:
# age
# 17      5
# 18     28
# 19     42
# 20     65
# 21    102
#      ...
# 91      2
# 92      4
# 94      1
# 95      1
# 98      2
# Name: y, Length: 78, dtype: int64

# %%
#We need to filter whar is the percentage of people above age 70 taken term deposit.
df1[df1['age']>70]
# Out:
# 0      age      job   marital            education  default housing loan
# 27758   76  retired   married    university.degree       no      no  yes  \
# 27781   73  retired   married    university.degree       no     yes   no
# 27801   88  retired  divorced             basic.4y       no     yes   no
# 27803   88  retired  divorced             basic.4y       no      no   no
# 27806   88  retired  divorced             basic.4y       no     yes  yes
# ...    ...      ...       ...                  ...      ...     ...  ...
# 40987   84  retired  divorced             basic.4y  unknown     yes  yes
# 40997   81  retired   married             basic.4y       no     yes   no
# 41005   80  retired   married  professional.course       no     yes   no
# 41184   73  retired   married  professional.course       no     yes   no
# 41188   74  retired   married  professional.course       no     yes   no
#
# 0       contact month day_of_week  ... campaign  pdays  previous     poutcome
# 27758  cellular   mar         thu  ...        9    999         0  nonexistent  \
# 27781  cellular   mar         tue  ...        1    999         1      failure
# 27801  cellular   mar         wed  ...        1    999         0  nonexistent
# 27803  cellular   mar         wed  ...        2    999         0  nonexistent
# 27806  cellular   mar         wed  ...        5    999         0  nonexistent
# ...         ...   ...         ...  ...      ...    ...       ...          ...
# 40987  cellular   oct         mon  ...        4      3         1      success
# 40997  cellular   oct         wed  ...        1    999         2      failure
# 41005  cellular   oct         thu  ...        1    999         1      failure
# 41184  cellular   nov         fri  ...        1    999         0  nonexistent
# 41188  cellular   nov         fri  ...        3    999         1      failure
#
# 0     emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 27758         -1.8          92.843          -50.0      1.757       5099.1   no
# 27781         -1.8          92.843          -50.0      1.687       5099.1   no
# 27801         -1.8          92.843          -50.0      1.663       5099.1   no
# 27803         -1.8          92.843          -50.0      1.663       5099.1  yes
# 27806         -1.8          92.843          -50.0      1.663       5099.1  yes
# ...            ...             ...            ...        ...          ...  ...
# 40987         -1.1          94.601          -49.5      1.000       4963.6   no
# 40997         -1.1          94.601          -49.5      1.016       4963.6  yes
# 41005         -1.1          94.601          -49.5      1.025       4963.6  yes
# 41184         -1.1          94.767          -50.8      1.028       4963.6  yes
# 41188         -1.1          94.767          -50.8      1.028       4963.6   no
#
# [422 rows x 21 columns]

# %%
df1[(df1['age']<70) & (df1['y'] == 'yes')]
# Out:
# 0      age           job   marital            education  default housing loan
# 76      41   blue-collar  divorced             basic.4y  unknown     yes   no  \
# 84      49  entrepreneur   married    university.degree  unknown     yes   no
# 89      49    technician   married             basic.9y       no      no   no
# 130     41    technician   married  professional.course  unknown     yes   no
# 140     45   blue-collar   married             basic.9y  unknown     yes   no
# ...    ...           ...       ...                  ...      ...     ...  ...
# 41174   62       retired   married    university.degree       no     yes   no
# 41175   62       retired   married    university.degree       no     yes   no
# 41179   62       retired   married    university.degree       no      no   no
# 41182   37         admin   married    university.degree       no     yes   no
# 41187   44    technician   married  professional.course       no      no   no
#
# 0        contact month day_of_week  ... campaign  pdays  previous
# 76     telephone   may         mon  ...        1    999         0  \
# 84     telephone   may         mon  ...        1    999         0
# 89     telephone   may         mon  ...        1    999         0
# 130    telephone   may         mon  ...        1    999         0
# 140    telephone   may         mon  ...        1    999         0
# ...          ...   ...         ...  ...      ...    ...       ...
# 41174   cellular   nov         thu  ...        1    999         2
# 41175   cellular   nov         thu  ...        1      1         6
# 41179   cellular   nov         thu  ...        2      6         3
# 41182   cellular   nov         fri  ...        1    999         0
# 41187   cellular   nov         fri  ...        1    999         0
#
# 0         poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m
# 76     nonexistent          1.1          93.994          -36.4      4.857  \
# 84     nonexistent          1.1          93.994          -36.4      4.857
# 89     nonexistent          1.1          93.994          -36.4      4.857
# 130    nonexistent          1.1          93.994          -36.4      4.857
# 140    nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41174      failure         -1.1          94.767          -50.8      1.031
# 41175      success         -1.1          94.767          -50.8      1.031
# 41179      success         -1.1          94.767          -50.8      1.031
# 41182  nonexistent         -1.1          94.767          -50.8      1.028
# 41187  nonexistent         -1.1          94.767          -50.8      1.028
#
# 0      nr.employed    y
# 76          5191.0  yes
# 84          5191.0  yes
# 89          5191.0  yes
# 130         5191.0  yes
# 140         5191.0  yes
# ...            ...  ...
# 41174       4963.6  yes
# 41175       4963.6  yes
# 41179       4963.6  yes
# 41182       4963.6  yes
# 41187       4963.6  yes
#
# [4419 rows x 21 columns]

# %%
df1[(df1['age']>70) & (df1['y'] == 'yes')]
# Out:
# 0      age      job   marital            education default housing loan
# 27803   88  retired  divorced             basic.4y      no      no   no  \
# 27806   88  retired  divorced             basic.4y      no     yes  yes
# 27811   88  retired  divorced             basic.4y      no     yes   no
# 27812   88  retired  divorced             basic.4y      no      no   no
# 27814   88  retired  divorced             basic.4y      no     yes   no
# ...    ...      ...       ...                  ...     ...     ...  ...
# 40757   77  retired   married             basic.4y      no     yes   no
# 40934   71  retired   married  professional.course      no      no   no
# 40997   81  retired   married             basic.4y      no     yes   no
# 41005   80  retired   married  professional.course      no     yes   no
# 41184   73  retired   married  professional.course      no     yes   no
#
# 0       contact month day_of_week  ... campaign  pdays  previous     poutcome
# 27803  cellular   mar         wed  ...        2    999         0  nonexistent  \
# 27806  cellular   mar         wed  ...        5    999         0  nonexistent
# 27811  cellular   mar         wed  ...        1    999         0  nonexistent
# 27812  cellular   mar         wed  ...        1    999         0  nonexistent
# 27814  cellular   mar         wed  ...        7    999         0  nonexistent
# ...         ...   ...         ...  ...      ...    ...       ...          ...
# 40757  cellular   sep         thu  ...        1    999         0  nonexistent
# 40934  cellular   oct         tue  ...        1    999         0  nonexistent
# 40997  cellular   oct         wed  ...        1    999         2      failure
# 41005  cellular   oct         thu  ...        1    999         1      failure
# 41184  cellular   nov         fri  ...        1    999         0  nonexistent
#
# 0     emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 27803         -1.8          92.843          -50.0      1.663       5099.1  yes
# 27806         -1.8          92.843          -50.0      1.663       5099.1  yes
# 27811         -1.8          92.843          -50.0      1.663       5099.1  yes
# 27812         -1.8          92.843          -50.0      1.663       5099.1  yes
# 27814         -1.8          92.843          -50.0      1.663       5099.1  yes
# ...            ...             ...            ...        ...          ...  ...
# 40757         -1.1          94.199          -37.5      0.879       4963.6  yes
# 40934         -1.1          94.601          -49.5      0.982       4963.6  yes
# 40997         -1.1          94.601          -49.5      1.016       4963.6  yes
# 41005         -1.1          94.601          -49.5      1.025       4963.6  yes
# 41184         -1.1          94.767          -50.8      1.028       4963.6  yes
#
# [202 rows x 21 columns]

# %%
sns.kdeplot(data=df1, x="age", hue="y");

# %%
df1_sub = df1[(df1["age"])&(df1["y"]=='yes')]
sns.boxplot(data=df1_sub, x="age", hue="y");

# %%
sns.catplot(data=df1_sub, x="marital", y="job");

# %%
df1[(df1['age']>80) & (df1['y'] == 'yes')]
# Out:
# 0      age        job   marital            education  default  housing
# 27803   88    retired  divorced             basic.4y       no       no  \
# 27806   88    retired  divorced             basic.4y       no      yes
# 27811   88    retired  divorced             basic.4y       no      yes
# 27812   88    retired  divorced             basic.4y       no       no
# 27814   88    retired  divorced             basic.4y       no      yes
# 27817   88    retired  divorced             basic.4y       no      yes
# 27818   88    retired  divorced             basic.4y       no       no
# 27819   88    retired  divorced             basic.4y       no      yes
# 28313   82    retired   married              unknown       no       no
# 30007   85    retired   married             basic.4y  unknown      yes
# 30590   81    retired   married             basic.4y       no       no
# 35834   81    retired  divorced              unknown  unknown      yes
# 37342   85    retired   married  professional.course       no       no
# 37744   87    retired  divorced             basic.4y       no       no
# 38137   81    retired   married             basic.4y       no      yes
# 38180   83    retired   married  professional.course       no      yes
# 38185   82    retired   married    university.degree       no      yes
# 38416   88    retired  divorced             basic.4y       no       no
# 38453   98    retired   married             basic.4y  unknown      yes
# 38456   98    retired   married             basic.4y  unknown      yes
# 38558   82    retired    single             basic.4y       no      yes
# 38698   81    unknown  divorced              unknown  unknown      yes
# 38701   81    unknown  divorced              unknown  unknown      yes
# 38893   82    retired  divorced             basic.4y       no      yes
# 38902   83    retired  divorced             basic.4y       no       no
# 38968   83    retired   married          high.school       no       no
# 39012   86    retired   married  professional.course       no       no
# 39033   81    retired  divorced             basic.4y       no      yes
# 39042   85    retired  divorced             basic.4y  unknown      yes
# 39043   84    retired   married          high.school       no       no
# 39276   82    retired   married  professional.course       no      yes
# 39412   82  housemaid  divorced             basic.4y       no  unknown
# 39467   82    retired  divorced             basic.4y       no      yes
# 39472   82    retired  divorced             basic.4y       no       no
# 39476   85  housemaid   married             basic.4y  unknown       no
# 39477   85  housemaid   married             basic.4y  unknown      yes
# 39480   85  housemaid   married             basic.4y  unknown      yes
# 39735   92    retired  divorced              unknown  unknown       no
# 39848   89    retired  divorced             basic.4y       no       no
# 39948   83    retired  divorced             basic.4y       no       no
# 40002   86    retired    single             basic.9y  unknown       no
# 40051   83  housemaid  divorced             basic.4y       no      yes
# 40118   83    retired   married    university.degree       no      yes
# 40120   83    retired   married    university.degree       no       no
# 40219   82  housemaid  divorced             basic.4y       no       no
# 40263   84    retired  divorced             basic.4y       no      yes
# 40451   92    retired   married              unknown       no       no
# 40470   92    retired   married              unknown       no       no
# 40576   81    retired  divorced             basic.4y       no       no
# 40639   85    retired   married             basic.4y       no       no
# 40640   89    retired  divorced             basic.4y       no      yes
# 40652   86    retired   married             basic.4y       no      yes
# 40687   83    retired  divorced             basic.4y       no       no
# 40715   84    retired  divorced              unknown  unknown       no
# 40717   82  housemaid   married             basic.4y       no       no
# 40719   86    retired   married              unknown  unknown      yes
# 40728   86    retired   married              unknown  unknown      yes
# 40749   82    retired  divorced             basic.4y       no      yes
# 40997   81    retired   married             basic.4y       no      yes
#
# 0         loan    contact month day_of_week  ... campaign  pdays  previous
# 27803       no   cellular   mar         wed  ...        2    999         0  \
# 27806      yes   cellular   mar         wed  ...        5    999         0
# 27811       no   cellular   mar         wed  ...        1    999         0
# 27812       no   cellular   mar         wed  ...        1    999         0
# 27814       no   cellular   mar         wed  ...        7    999         0
# 27817       no   cellular   mar         wed  ...        3    999         0
# 27818       no   cellular   mar         wed  ...        2    999         0
# 27819       no   cellular   mar         wed  ...        1    999         0
# 28313       no   cellular   apr         wed  ...        1    999         0
# 30007       no   cellular   apr         tue  ...        3    999         0
# 30590       no   cellular   may         mon  ...        2    999         0
# 35834      yes   cellular   may         fri  ...        1    999         0
# 37342       no   cellular   aug         tue  ...        1    999         0
# 37744       no   cellular   aug         fri  ...        1    999         0
# 38137       no   cellular   sep         fri  ...        1    999         0
# 38180       no   cellular   oct         fri  ...        2      4         1
# 38185       no   cellular   oct         tue  ...        1    999         0
# 38416       no   cellular   oct         wed  ...        2      6         1
# 38453       no   cellular   oct         fri  ...        1      2         2
# 38456       no   cellular   oct         fri  ...        2    999         0
# 38558       no   cellular   oct         thu  ...        2    999         0
# 38698       no   cellular   nov         mon  ...        1    999         1
# 38701       no   cellular   nov         mon  ...        1    999         1
# 38893       no   cellular   nov         tue  ...        2      3         1
# 38902       no   cellular   nov         tue  ...        1      3         3
# 38968       no   cellular   dec         thu  ...        1      4         3
# 39012       no  telephone   dec         wed  ...        2    999         0
# 39033       no   cellular   dec         fri  ...        3    999         0
# 39042       no   cellular   dec         mon  ...        3      6         1
# 39043       no   cellular   dec         tue  ...        1    999         0
# 39276       no  telephone   mar         mon  ...        2    999         0
# 39412  unknown   cellular   apr         tue  ...        6    999         0
# 39467      yes   cellular   apr         mon  ...        2    999         0
# 39472       no   cellular   apr         mon  ...        1      6         2
# 39476       no   cellular   apr         tue  ...        6      6         1
# 39477       no   cellular   apr         tue  ...        1      6         2
# 39480       no   cellular   apr         tue  ...        1    999         1
# 39735       no   cellular   may         wed  ...        3    999         1
# 39848       no   cellular   jun         mon  ...        1    999         0
# 39948      yes   cellular   jun         fri  ...        2    999         0
# 40002       no  telephone   jun         wed  ...        1    999         0
# 40051       no   cellular   jul         tue  ...        2      3         1
# 40118       no   cellular   jul         tue  ...        1      6         2
# 40120       no  telephone   jul         tue  ...        1     12         1
# 40219       no   cellular   jul         wed  ...        1    999         0
# 40263      yes   cellular   jul         tue  ...        1      3         2
# 40451      yes   cellular   aug         tue  ...        1      3         1
# 40470      yes   cellular   aug         wed  ...        1      3         4
# 40576       no   cellular   sep         wed  ...        2      7         1
# 40639       no   cellular   sep         tue  ...        1      3         2
# 40640       no   cellular   sep         tue  ...        1    999         0
# 40652       no   cellular   sep         tue  ...        3    999         0
# 40687       no   cellular   sep         thu  ...        1      9         3
# 40715       no   cellular   sep         tue  ...        1      3         2
# 40717       no  telephone   sep         tue  ...        3      3         2
# 40719      yes   cellular   sep         tue  ...        1      7         4
# 40728       no   cellular   sep         tue  ...        1    999         0
# 40749       no   cellular   sep         thu  ...        2    999         1
# 40997       no   cellular   oct         wed  ...        1    999         2
#
# 0         poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m
# 27803  nonexistent         -1.8          92.843          -50.0      1.663  \
# 27806  nonexistent         -1.8          92.843          -50.0      1.663
# 27811  nonexistent         -1.8          92.843          -50.0      1.663
# 27812  nonexistent         -1.8          92.843          -50.0      1.663
# 27814  nonexistent         -1.8          92.843          -50.0      1.663
# 27817  nonexistent         -1.8          92.843          -50.0      1.663
# 27818  nonexistent         -1.8          92.843          -50.0      1.663
# 27819  nonexistent         -1.8          92.843          -50.0      1.663
# 28313  nonexistent         -1.8          93.075          -47.1      1.445
# 30007  nonexistent         -1.8          93.075          -47.1      1.405
# 30590  nonexistent         -1.8          92.893          -46.2      1.354
# 35834  nonexistent         -1.8          92.893          -46.2      1.259
# 37342  nonexistent         -2.9          92.201          -31.4      0.883
# 37744  nonexistent         -2.9          92.201          -31.4      0.849
# 38137  nonexistent         -3.4          92.379          -29.8      0.741
# 38180      success         -3.4          92.431          -26.9      0.752
# 38185  nonexistent         -3.4          92.431          -26.9      0.744
# 38416      success         -3.4          92.431          -26.9      0.735
# 38453      success         -3.4          92.431          -26.9      0.730
# 38456  nonexistent         -3.4          92.431          -26.9      0.730
# 38558  nonexistent         -3.4          92.431          -26.9      0.722
# 38698      failure         -3.4          92.649          -30.1      0.715
# 38701      failure         -3.4          92.649          -30.1      0.715
# 38893      success         -3.4          92.649          -30.1      0.715
# 38902      success         -3.4          92.649          -30.1      0.716
# 38968      success         -3.0          92.713          -33.0      0.720
# 39012  nonexistent         -3.0          92.713          -33.0      0.715
# 39033  nonexistent         -3.0          92.713          -33.0      0.714
# 39042      success         -3.0          92.713          -33.0      0.715
# 39043  nonexistent         -3.0          92.713          -33.0      0.715
# 39276  nonexistent         -1.8          93.369          -34.8      0.646
# 39412  nonexistent         -1.8          93.749          -34.6      0.638
# 39467  nonexistent         -1.8          93.749          -34.6      0.643
# 39472      success         -1.8          93.749          -34.6      0.643
# 39476      success         -1.8          93.749          -34.6      0.642
# 39477      success         -1.8          93.749          -34.6      0.642
# 39480      failure         -1.8          93.749          -34.6      0.642
# 39735      failure         -1.8          93.876          -40.0      0.697
# 39848  nonexistent         -1.7          94.055          -39.8      0.720
# 39948  nonexistent         -1.7          94.055          -39.8      0.748
# 40002  nonexistent         -1.7          94.055          -39.8      0.767
# 40051      success         -1.7          94.215          -40.3      0.797
# 40118      success         -1.7          94.215          -40.3      0.835
# 40120      success         -1.7          94.215          -40.3      0.835
# 40219  nonexistent         -1.7          94.215          -40.3      0.881
# 40263      success         -1.7          94.215          -40.3      0.893
# 40451      success         -1.7          94.027          -38.3      0.904
# 40470      success         -1.7          94.027          -38.3      0.903
# 40576      success         -1.1          94.199          -37.5      0.886
# 40639      success         -1.1          94.199          -37.5      0.881
# 40640  nonexistent         -1.1          94.199          -37.5      0.881
# 40652  nonexistent         -1.1          94.199          -37.5      0.881
# 40687      success         -1.1          94.199          -37.5      0.879
# 40715      success         -1.1          94.199          -37.5      0.877
# 40717      success         -1.1          94.199          -37.5      0.877
# 40719      success         -1.1          94.199          -37.5      0.877
# 40728  nonexistent         -1.1          94.199          -37.5      0.877
# 40749      failure         -1.1          94.199          -37.5      0.879
# 40997      failure         -1.1          94.601          -49.5      1.016
#
# 0      nr.employed    y
# 27803       5099.1  yes
# 27806       5099.1  yes
# 27811       5099.1  yes
# 27812       5099.1  yes
# 27814       5099.1  yes
# 27817       5099.1  yes
# 27818       5099.1  yes
# 27819       5099.1  yes
# 28313       5099.1  yes
# 30007       5099.1  yes
# 30590       5099.1  yes
# 35834       5099.1  yes
# 37342       5076.2  yes
# 37744       5076.2  yes
# 38137       5017.5  yes
# 38180       5017.5  yes
# 38185       5017.5  yes
# 38416       5017.5  yes
# 38453       5017.5  yes
# 38456       5017.5  yes
# 38558       5017.5  yes
# 38698       5017.5  yes
# 38701       5017.5  yes
# 38893       5017.5  yes
# 38902       5017.5  yes
# 38968       5023.5  yes
# 39012       5023.5  yes
# 39033       5023.5  yes
# 39042       5023.5  yes
# 39043       5023.5  yes
# 39276       5008.7  yes
# 39412       5008.7  yes
# 39467       5008.7  yes
# 39472       5008.7  yes
# 39476       5008.7  yes
# 39477       5008.7  yes
# 39480       5008.7  yes
# 39735       5008.7  yes
# 39848       4991.6  yes
# 39948       4991.6  yes
# 40002       4991.6  yes
# 40051       4991.6  yes
# 40118       4991.6  yes
# 40120       4991.6  yes
# 40219       4991.6  yes
# 40263       4991.6  yes
# 40451       4991.6  yes
# 40470       4991.6  yes
# 40576       4963.6  yes
# 40639       4963.6  yes
# 40640       4963.6  yes
# 40652       4963.6  yes
# 40687       4963.6  yes
# 40715       4963.6  yes
# 40717       4963.6  yes
# 40719       4963.6  yes
# 40728       4963.6  yes
# 40749       4963.6  yes
# 40997       4963.6  yes
#
# [59 rows x 21 columns]

# %%
sns.countplot(x="y", data=df1);

# %%
sns.countplot(x="y", hue="job", data=df1);

# %%
sns.countplot(y="education", hue="y", data=df1);

# %%
sns.countplot(x="y", hue="education", data=df1);

# %%
sns.countplot(y="education", hue="y", data=df1);

# %%
df1_loan_subset = df1[(df1['default']=='no') & (df1['housing'] == 'yes')& (df1['loan'] == 'yes')]
df1_loan_subset
# Out:
# 0      age          job   marital            education default housing loan
# 19      50  blue-collar   married             basic.9y      no     yes  yes  \
# 47      57        admin   married    university.degree      no     yes  yes
# 88      39        admin   married    university.degree      no     yes  yes
# 125     32        admin   married    university.degree      no     yes  yes
# 128     31   technician  divorced  professional.course      no     yes  yes
# ...    ...          ...       ...                  ...     ...     ...  ...
# 41084   24   technician    single    university.degree      no     yes  yes
# 41086   51        admin  divorced          high.school      no     yes  yes
# 41099   29      student    single          high.school      no     yes  yes
# 41128   61        admin   married          high.school      no     yes  yes
# 41177   38    housemaid  divorced          high.school      no     yes  yes
#
# 0        contact month day_of_week  ... campaign  pdays  previous
# 19     telephone   may         mon  ...        1    999         0  \
# 47     telephone   may         mon  ...        1    999         0
# 88     telephone   may         mon  ...        1    999         0
# 125    telephone   may         mon  ...        1    999         0
# 128    telephone   may         mon  ...        1    999         0
# ...          ...   ...         ...  ...      ...    ...       ...
# 41084   cellular   nov         tue  ...        3      6         3
# 41086   cellular   nov         tue  ...        2      6         4
# 41099   cellular   nov         thu  ...        1      3         3
# 41128   cellular   nov         wed  ...        2    999         0
# 41177   cellular   nov         thu  ...        1    999         0
#
# 0         poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m
# 19     nonexistent          1.1          93.994          -36.4      4.857  \
# 47     nonexistent          1.1          93.994          -36.4      4.857
# 88     nonexistent          1.1          93.994          -36.4      4.857
# 125    nonexistent          1.1          93.994          -36.4      4.857
# 128    nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41084      failure         -1.1          94.767          -50.8      1.049
# 41086      failure         -1.1          94.767          -50.8      1.049
# 41099      success         -1.1          94.767          -50.8      1.050
# 41128  nonexistent         -1.1          94.767          -50.8      1.044
# 41177  nonexistent         -1.1          94.767          -50.8      1.031
#
# 0      nr.employed    y
# 19          5191.0   no
# 47          5191.0   no
# 88          5191.0   no
# 125         5191.0   no
# 128         5191.0   no
# ...            ...  ...
# 41084       4963.6  yes
# 41086       4963.6  yes
# 41099       4963.6  yes
# 41128       4963.6  yes
# 41177       4963.6   no
#
# [2968 rows x 21 columns]

# %%
sns.countplot(y="marital", hue="y", data=df1_loan_subset);

# %%
df1[(df1['default']=='no') & (df1['housing'] == 'no')& (df1['loan'] == 'yes')]
# Out:
# 0      age          job  marital            education default housing loan
# 5       56     services  married          high.school      no      no  yes  \
# 13      29  blue-collar   single          high.school      no      no  yes
# 26      35   technician  married    university.degree      no      no  yes
# 44      57        admin  married    university.degree      no      no  yes
# 48      40  blue-collar  married             basic.9y      no      no  yes
# ...    ...          ...      ...                  ...     ...     ...  ...
# 41070   51     services  married          high.school      no      no  yes
# 41081   27      student   single          high.school      no      no  yes
# 41091   31        admin   single    university.degree      no      no  yes
# 41112   46        admin   single    university.degree      no      no  yes
# 41144   29   technician   single  professional.course      no      no  yes
#
# 0        contact month day_of_week  ... campaign  pdays  previous
# 5      telephone   may         mon  ...        1    999         0  \
# 13     telephone   may         mon  ...        1    999         0
# 26     telephone   may         mon  ...        1    999         0
# 44     telephone   may         mon  ...        1    999         0
# 48     telephone   may         mon  ...        1    999         0
# ...          ...   ...         ...  ...      ...    ...       ...
# 41070   cellular   nov         mon  ...        2      3         4
# 41081   cellular   nov         tue  ...        1    999         0
# 41091   cellular   nov         wed  ...        2      3         6
# 41112   cellular   nov         tue  ...        1    999         1
# 41144   cellular   nov         fri  ...        1      6         2
#
# 0         poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m
# 5      nonexistent          1.1          93.994          -36.4      4.857  \
# 13     nonexistent          1.1          93.994          -36.4      4.857
# 26     nonexistent          1.1          93.994          -36.4      4.857
# 44     nonexistent          1.1          93.994          -36.4      4.857
# 48     nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41070      success         -1.1          94.767          -50.8      1.050
# 41081  nonexistent         -1.1          94.767          -50.8      1.049
# 41091      success         -1.1          94.767          -50.8      1.048
# 41112      failure         -1.1          94.767          -50.8      1.046
# 41144      success         -1.1          94.767          -50.8      1.040
#
# 0      nr.employed   y
# 5           5191.0  no
# 13          5191.0  no
# 26          5191.0  no
# 44          5191.0  no
# 48          5191.0  no
# ...            ...  ..
# 41070       4963.6  no
# 41081       4963.6  no
# 41091       4963.6  no
# 41112       4963.6  no
# 41144       4963.6  no
#
# [2008 rows x 21 columns]

# %% [markdown]
# ## Finding correlation between Numeric features
# ### Correlation between Numeric features

# %%
df1.hist(figsize=(12,12));

# %%
df1_nu_corr = df1[["age", "campaign", "pdays", "previous", "emp.var.rate", "cons.price.idx", "cons.conf.idx", "euribor3m", "nr.employed"]].corr()
df1_nu_corr
# Out:
# 0                    age  campaign     pdays  previous  emp.var.rate
# 0
# age             1.000000  0.004594 -0.034369  0.024365     -0.000371  \
# campaign        0.004594  1.000000  0.052584 -0.079141      0.150754
# pdays          -0.034369  0.052584  1.000000 -0.587514      0.271004
# previous        0.024365 -0.079141 -0.587514  1.000000     -0.420489
# emp.var.rate   -0.000371  0.150754  0.271004 -0.420489      1.000000
# cons.price.idx  0.000857  0.127836  0.078889 -0.203130      0.775334
# cons.conf.idx   0.129372 -0.013733 -0.091342 -0.050936      0.196041
# euribor3m       0.010767  0.135133  0.296899 -0.454494      0.972245
# nr.employed    -0.017725  0.144095  0.372605 -0.501333      0.906970
#
# 0               cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# 0
# age                   0.000857       0.129372   0.010767    -0.017725
# campaign              0.127836      -0.013733   0.135133     0.144095
# pdays                 0.078889      -0.091342   0.296899     0.372605
# previous             -0.203130      -0.050936  -0.454494    -0.501333
# emp.var.rate          0.775334       0.196041   0.972245     0.906970
# cons.price.idx        1.000000       0.058986   0.688230     0.522034
# cons.conf.idx         0.058986       1.000000   0.277686     0.100513
# euribor3m             0.688230       0.277686   1.000000     0.945154
# nr.employed           0.522034       0.100513   0.945154     1.000000

# %%
fig= plt.figure(figsize=(15,12));
sns.heatmap(df1_nu_corr,annot=True,cmap="RdYlGn");
plt.show();

# %% [markdown]
# ##  Correlation between categorical features - Chi2 Test

# %%
def is_correlated(x,y):
    ct=pd.crosstab(index=df1[x], columns= df1[y])
    chi_sq_result = chi2_contingency(ct,)
    p,x = chi_sq_result[1], "correlated" if chi_sq_result[1] < 0.05 else "not-correlated"
    return p,x

# %%
print("The p-value and correlation for job:", is_correlated('job','y'))
print("The p-value and correlation for marital:", is_correlated('marital','y'))
print("The p-value and correlation for education:", is_correlated('education','y'))
print("The p-value and correlation for default:", is_correlated('default','y'))
print("The p-value and correlation for housing:", is_correlated('housing','y'))
print("The p-value and correlation for loan:", is_correlated('loan','y'))
print("The p-value and correlation for contact:", is_correlated('contact','y'))
print("The p-value and correlation for day_of_week:", is_correlated('day_of_week','y'))
print("The p-value and correlation for poutcome:", is_correlated('poutcome','y'))
# Out:
# The p-value and correlation for job: (4.189763287563623e-199, 'correlated')
# The p-value and correlation for marital: (2.068014648442211e-26, 'correlated')
# The p-value and correlation for education: (3.3051890144025054e-38, 'correlated')
# The p-value and correlation for default: (5.161957951391637e-89, 'correlated')
# The p-value and correlation for housing: (0.05829447669453452, 'not-correlated')
# The p-value and correlation for loan: (0.5786752870441754, 'not-correlated')
# The p-value and correlation for contact: (1.525985652312996e-189, 'correlated')
# The p-value and correlation for day_of_week: (2.958482005278532e-05, 'correlated')
# The p-value and correlation for poutcome: (0.0, 'correlated')

# %%
df1[(df1['default']=='"yes"') & (df1['housing'] == '"no"')& (df1['loan'] == '"no"')]
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y]
# Index: []
#
# [0 rows x 21 columns]

# %%
df1[(df1['default']=='yes') & (df1['housing'] == 'yes')& (df1['loan'] == 'no')]
# Out:
# 0      age         job  marital            education default housing loan
# 21582   48  technician  married  professional.course     yes     yes   no  \
#
# 0       contact month day_of_week  ... campaign  pdays  previous     poutcome
# 21582  cellular   aug         tue  ...        1    999         0  nonexistent  \
#
# 0     emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 21582          1.4          93.444          -36.1      4.963       5228.1  no
#
# [1 rows x 21 columns]

# %%
df1[(df1['default']=='yes') & (df1['housing'] == 'yes')& (df1['loan'] == 'yes')]
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ## Label Encoding for Target Variable

# %%
label_encoder = preprocessing.LabelEncoder()
# Encode labels in column 'species'.
df1['y']= label_encoder.fit_transform(df1['y'])

df1['y'].unique()
# Out:
# array([0, 1])

# %%
df1
# Out:
# 0      age          job  marital            education  default housing loan
# 1       56    housemaid  married             basic.4y       no      no   no  \
# 2       57     services  married          high.school  unknown      no   no
# 3       37     services  married          high.school       no     yes   no
# 4       40        admin  married             basic.6y       no      no   no
# 5       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41184   73      retired  married  professional.course       no     yes   no
# 41185   46  blue-collar  married  professional.course       no      no   no
# 41186   56      retired  married    university.degree       no     yes   no
# 41187   44   technician  married  professional.course       no      no   no
# 41188   74      retired  married  professional.course       no     yes   no
#
# 0        contact month day_of_week  ... campaign  pdays  previous
# 1      telephone   may         mon  ...        1    999         0  \
# 2      telephone   may         mon  ...        1    999         0
# 3      telephone   may         mon  ...        1    999         0
# 4      telephone   may         mon  ...        1    999         0
# 5      telephone   may         mon  ...        1    999         0
# ...          ...   ...         ...  ...      ...    ...       ...
# 41184   cellular   nov         fri  ...        1    999         0
# 41185   cellular   nov         fri  ...        1    999         0
# 41186   cellular   nov         fri  ...        2    999         0
# 41187   cellular   nov         fri  ...        1    999         0
# 41188   cellular   nov         fri  ...        3    999         1
#
# 0         poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m
# 1      nonexistent          1.1          93.994          -36.4      4.857  \
# 2      nonexistent          1.1          93.994          -36.4      4.857
# 3      nonexistent          1.1          93.994          -36.4      4.857
# 4      nonexistent          1.1          93.994          -36.4      4.857
# 5      nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41184  nonexistent         -1.1          94.767          -50.8      1.028
# 41185  nonexistent         -1.1          94.767          -50.8      1.028
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187  nonexistent         -1.1          94.767          -50.8      1.028
# 41188      failure         -1.1          94.767          -50.8      1.028
#
# 0      nr.employed  y
# 1           5191.0  0
# 2           5191.0  0
# 3           5191.0  0
# 4           5191.0  0
# 5           5191.0  0
# ...            ... ..
# 41184       4963.6  1
# 41185       4963.6  0
# 41186       4963.6  0
# 41187       4963.6  1
# 41188       4963.6  0
#
# [41188 rows x 21 columns]

# %%
df1_nu_corr = df1[["age", "campaign", "pdays", "previous", "emp.var.rate", "cons.price.idx", "cons.conf.idx", "euribor3m", "nr.employed", "y"]].corr()
df1_nu_corr
# Out:
# 0                    age  campaign     pdays  previous  emp.var.rate
# 0
# age             1.000000  0.004594 -0.034369  0.024365     -0.000371  \
# campaign        0.004594  1.000000  0.052584 -0.079141      0.150754
# pdays          -0.034369  0.052584  1.000000 -0.587514      0.271004
# previous        0.024365 -0.079141 -0.587514  1.000000     -0.420489
# emp.var.rate   -0.000371  0.150754  0.271004 -0.420489      1.000000
# cons.price.idx  0.000857  0.127836  0.078889 -0.203130      0.775334
# cons.conf.idx   0.129372 -0.013733 -0.091342 -0.050936      0.196041
# euribor3m       0.010767  0.135133  0.296899 -0.454494      0.972245
# nr.employed    -0.017725  0.144095  0.372605 -0.501333      0.906970
# y               0.030399 -0.066357 -0.324914  0.230181     -0.298334
#
# 0               cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# 0
# age                   0.000857       0.129372   0.010767    -0.017725  \
# campaign              0.127836      -0.013733   0.135133     0.144095
# pdays                 0.078889      -0.091342   0.296899     0.372605
# previous             -0.203130      -0.050936  -0.454494    -0.501333
# emp.var.rate          0.775334       0.196041   0.972245     0.906970
# cons.price.idx        1.000000       0.058986   0.688230     0.522034
# cons.conf.idx         0.058986       1.000000   0.277686     0.100513
# euribor3m             0.688230       0.277686   1.000000     0.945154
# nr.employed           0.522034       0.100513   0.945154     1.000000
# y                    -0.136211       0.054878  -0.307771    -0.354678
#
# 0                      y
# 0
# age             0.030399
# campaign       -0.066357
# pdays          -0.324914
# previous        0.230181
# emp.var.rate   -0.298334
# cons.price.idx -0.136211
# cons.conf.idx   0.054878
# euribor3m      -0.307771
# nr.employed    -0.354678
# y               1.000000

# %%
fig= plt.figure(figsize=(20,20));
sns.heatmap(df1_nu_corr,annot=True,cmap="RdYlGn");
plt.show();
# RdYlGn
# BuGn_r

# %% [markdown]
# ## Dropping features

# %%
df1.drop(["age", "housing", "loan"], axis=1, inplace=True)

# %%
df1
# Out:
# 0              job  marital            education  default    contact month
# 1        housemaid  married             basic.4y       no  telephone   may  \
# 2         services  married          high.school  unknown  telephone   may
# 3         services  married          high.school       no  telephone   may
# 4            admin  married             basic.6y       no  telephone   may
# 5         services  married          high.school       no  telephone   may
# ...            ...      ...                  ...      ...        ...   ...
# 41184      retired  married  professional.course       no   cellular   nov
# 41185  blue-collar  married  professional.course       no   cellular   nov
# 41186      retired  married    university.degree       no   cellular   nov
# 41187   technician  married  professional.course       no   cellular   nov
# 41188      retired  married  professional.course       no   cellular   nov
#
# 0     day_of_week duration  campaign  pdays  previous     poutcome
# 1             mon      261         1    999         0  nonexistent  \
# 2             mon      149         1    999         0  nonexistent
# 3             mon      226         1    999         0  nonexistent
# 4             mon      151         1    999         0  nonexistent
# 5             mon      307         1    999         0  nonexistent
# ...           ...      ...       ...    ...       ...          ...
# 41184         fri      334         1    999         0  nonexistent
# 41185         fri      383         1    999         0  nonexistent
# 41186         fri      189         2    999         0  nonexistent
# 41187         fri      442         1    999         0  nonexistent
# 41188         fri      239         3    999         1      failure
#
# 0      emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# 1               1.1          93.994          -36.4      4.857       5191.0  0
# 2               1.1          93.994          -36.4      4.857       5191.0  0
# 3               1.1          93.994          -36.4      4.857       5191.0  0
# 4               1.1          93.994          -36.4      4.857       5191.0  0
# 5               1.1          93.994          -36.4      4.857       5191.0  0
# ...             ...             ...            ...        ...          ... ..
# 41184          -1.1          94.767          -50.8      1.028       4963.6  1
# 41185          -1.1          94.767          -50.8      1.028       4963.6  0
# 41186          -1.1          94.767          -50.8      1.028       4963.6  0
# 41187          -1.1          94.767          -50.8      1.028       4963.6  1
# 41188          -1.1          94.767          -50.8      1.028       4963.6  0
#
# [41188 rows x 18 columns]

# %%
## One-hot Encoding

### To create model and evaluate, we are creating categorical features into numeric one, by using One-hot Encoding for categorical data

# %%
df2 =df1

# %%
job_col_du = pd.get_dummies(df2['job'], prefix='job_du')
edu_col_du = pd.get_dummies(df2['education'], prefix='edu_du')
marital_col_du = pd.get_dummies(df2['marital'], prefix='marital_du')
edu_col_du = pd.get_dummies(df2['default'], prefix='default_du')
contact_col_du = pd.get_dummies(df2['contact'], prefix='contact_du')
month_col_du = pd.get_dummies(df2['month'], prefix='month_du')
day_col_du = pd.get_dummies(df2['day_of_week'], prefix='day_du')
pout_col_du = pd.get_dummies(df2['poutcome'], prefix='pout_du')

# %%
df2 = pd.concat([df2, job_col_du, edu_col_du, marital_col_du, edu_col_du, contact_col_du , month_col_du, day_col_du, pout_col_du], axis=1)

# %%
df2.drop(["job", "education", "marital", "default", "contact", "month", "day_of_week", "poutcome"], axis=1, inplace=True)

# %%
df2
# Out:
#       duration  campaign  pdays  previous  emp.var.rate  cons.price.idx
# 1          261         1    999         0           1.1          93.994  \
# 2          149         1    999         0           1.1          93.994
# 3          226         1    999         0           1.1          93.994
# 4          151         1    999         0           1.1          93.994
# 5          307         1    999         0           1.1          93.994
# ...        ...       ...    ...       ...           ...             ...
# 41184      334         1    999         0          -1.1          94.767
# 41185      383         1    999         0          -1.1          94.767
# 41186      189         2    999         0          -1.1          94.767
# 41187      442         1    999         0          -1.1          94.767
# 41188      239         3    999         1          -1.1          94.767
#
#        cons.conf.idx  euribor3m  nr.employed  y  ...  month_du_oct
# 1              -36.4      4.857       5191.0  0  ...         False  \
# 2              -36.4      4.857       5191.0  0  ...         False
# 3              -36.4      4.857       5191.0  0  ...         False
# 4              -36.4      4.857       5191.0  0  ...         False
# 5              -36.4      4.857       5191.0  0  ...         False
# ...              ...        ...          ... ..  ...           ...
# 41184          -50.8      1.028       4963.6  1  ...         False
# 41185          -50.8      1.028       4963.6  0  ...         False
# 41186          -50.8      1.028       4963.6  0  ...         False
# 41187          -50.8      1.028       4963.6  1  ...         False
# 41188          -50.8      1.028       4963.6  0  ...         False
#
#        month_du_sep  day_du_fri  day_du_mon  day_du_thu  day_du_tue
# 1             False       False        True       False       False  \
# 2             False       False        True       False       False
# 3             False       False        True       False       False
# 4             False       False        True       False       False
# 5             False       False        True       False       False
# ...             ...         ...         ...         ...         ...
# 41184         False        True       False       False       False
# 41185         False        True       False       False       False
# 41186         False        True       False       False       False
# 41187         False        True       False       False       False
# 41188         False        True       False       False       False
#
#        day_du_wed  pout_du_failure  pout_du_nonexistent  pout_du_success
# 1           False            False                 True            False
# 2           False            False                 True            False
# 3           False            False                 True            False
# 4           False            False                 True            False
# 5           False            False                 True            False
# ...           ...              ...                  ...              ...
# 41184       False            False                 True            False
# 41185       False            False                 True            False
# 41186       False            False                 True            False
# 41187       False            False                 True            False
# 41188       False             True                False            False
#
# [41188 rows x 52 columns]

# %% [markdown]
# ## Support Vector Mechine (SVM) - Model
#
# ### SVM using Linear Kernal

# %%
x= df2.drop('y',axis=1)
y= df2['y']

# %% [markdown]
# ##  SVM Linear Model Test Size 0.2
#
# ### Training model

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
model1=SVC(kernel ='linear')

# training set in x, y axis
result1=model1.fit(x_train,y_train)
y_pred1=result1.predict(x_test)

# %%
print("For test size:0.2, Accuracy Of SVM: ", accuracy_score(y_pred1,y_test))
print(classification_report(y_pred1,y_test))
# Out:
# For test size:0.2, Accuracy Of SVM:  0.9081087642631707
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95      7684
#            1       0.39      0.64      0.49       554
#
#     accuracy                           0.91      8238
#    macro avg       0.68      0.79      0.72      8238
# weighted avg       0.93      0.91      0.92      8238

# %% [markdown]
# ## SVM Linear Model Test Size 0.25
#
# ### Training model

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)
model2=SVC(kernel ='linear')

# training set in x, y axis
result2=model2.fit(x_train,y_train)
y_pred2=result2.predict(x_test)

# %%
print("For test size:0.25, Accuracy Of SVM: ", accuracy_score(y_pred2,y_test))
print(classification_report(y_pred2,y_test))
# Out:
# For test size:0.25, Accuracy Of SVM:  0.9095853161114887
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95      9646
#            1       0.37      0.63      0.47       651
#
#     accuracy                           0.91     10297
#    macro avg       0.67      0.78      0.71     10297
# weighted avg       0.94      0.91      0.92     10297

# %% [markdown]
# ## SVM Linear Model Test Size 0.30
#
# ### Training Model

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
model3=SVC(kernel ='linear')

# training set in x, y axis
result3=model3.fit(x_train,y_train)
y_pred3=result3.predict(x_test)

# %%
print("For test size:0.3, Accuracy Of SVM: ", accuracy_score(y_pred3,y_test))
print(classification_report(y_pred3,y_test))
# Out:
# For test size:0.3, Accuracy Of SVM:  0.8972242453669984
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94     11273
#            1       0.44      0.59      0.50      1084
#
#     accuracy                           0.90     12357
#    macro avg       0.70      0.76      0.72     12357
# weighted avg       0.91      0.90      0.90     12357

# %% [markdown]
# ## SVM using kernal
#
# ### Training model

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)
model4 = SVC(kernel ='rbf', random_state = 0)

# training set in x, y axis
result4 = model4.fit(x_train, y_train)
y_pred4=result4.predict(x_test)

# %%
print("For test size:0.25, Accuracy Of SVM kernal: ", accuracy_score(y_pred4,y_test))
print(classification_report(y_pred4,y_test))
# Out:
# For test size:0.25, Accuracy Of SVM kernal:  0.8972516266873847
#               precision    recall  f1-score   support
#
#            0       0.98      0.91      0.94      9882
#            1       0.23      0.65      0.34       415
#
#     accuracy                           0.90     10297
#    macro avg       0.61      0.78      0.64     10297
# weighted avg       0.95      0.90      0.92     10297

# %% [markdown]
# ## SVM using sigmoid kernal
#
# ### Training model

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)
model5 = SVC(kernel ='sigmoid')

# training set in x, y axis
result5 = model5.fit(x_train, y_train)
y_pred5=result5.predict(x_test)

# %%
print("For test size:0.25, Accuracy Of SVM sigmoid kernal: ", accuracy_score(y_pred5,y_test))
print(classification_report(y_pred5,y_test))
# Out:
# For test size:0.25, Accuracy Of SVM sigmoid kernal:  0.8987083616587356
#               precision    recall  f1-score   support
#
#            0       0.99      0.91      0.95      9897
#            1       0.23      0.67      0.34       400
#
#     accuracy                           0.90     10297
#    macro avg       0.61      0.79      0.64     10297
# weighted avg       0.96      0.90      0.92     10297

# %% [markdown]
# ## SVM using Polynomial kernal
#
# ### Training model

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)
model6 = SVC(kernel ='poly')

# training set in x, y axis
result6 = model6.fit(x_train, y_train)
y_pred6=result6.predict(x_test)

# %%
print("For test size:0.25, Accuracy Of SVM sigmoid kernal: ", accuracy_score(y_pred6,y_test))
print(classification_report(y_pred6,y_test))
# Out:
# For test size:0.25, Accuracy Of SVM sigmoid kernal:  0.8972516266873847
#               precision    recall  f1-score   support
#
#            0       0.99      0.91      0.94      9910
#            1       0.22      0.66      0.32       387
#
#     accuracy                           0.90     10297
#    macro avg       0.60      0.78      0.63     10297
# weighted avg       0.96      0.90      0.92     10297

# %% [markdown]
# ##  SVM using Polynomial kernal with degree of polynomial = 2

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)
model7 = SVC(kernel ='poly', degree = 2)

# training set in x, y axis
result7 = model7.fit(x_train, y_train)
y_pred7=result7.predict(x_test)

# %%
print("For test size:0.25, Accuracy Of SVM sigmoid kernal: ", accuracy_score(y_pred7,y_test))
print(classification_report(y_pred7,y_test))
# Out:
# For test size:0.25, Accuracy Of SVM sigmoid kernal:  0.8941439254151695
#               precision    recall  f1-score   support
#
#            0       0.99      0.90      0.94      9903
#            1       0.22      0.67      0.33       394
#
#     accuracy                           0.89     10297
#    macro avg       0.60      0.79      0.63     10297
# weighted avg       0.96      0.89      0.92     10297
